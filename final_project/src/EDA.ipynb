# %%
import pandas as pd
import numpy as np
import os
import sys
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, StandardScaler

# %%
import os,sys
sys.path.insert(0, os.path.abspath('../data/'))

# %%
df = pd.read_csv(r"../data/car_data.csv")

# %%
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_a1faa_row0_col0, #T_a1faa_row1_col1, #T_a1faa_row2_col2, #T_a1faa_row3_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_a1faa_row0_col1, #T_a1faa_row0_col2, #T_a1faa_row0_col3, #T_a1faa_row2_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_a1faa_row1_col0, #T_a1faa_row3_col0 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_a1faa_row1_col2 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_a1faa_row1_col3 {
#   background-color: #f3c8b2;
#   color: #000000;
# }
# #T_a1faa_row2_col1 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_a1faa_row2_col3 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_a1faa_row3_col1 {
#   background-color: #f2c9b4;
#   color: #000000;
# }
# #T_a1faa_row3_col2 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# </style>
# <table id="T_a1faa">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a1faa_level0_col0" class="col_heading level0 col0" >User ID</th>
#       <th id="T_a1faa_level0_col1" class="col_heading level0 col1" >Age</th>
#       <th id="T_a1faa_level0_col2" class="col_heading level0 col2" >AnnualSalary</th>
#       <th id="T_a1faa_level0_col3" class="col_heading level0 col3" >Purchased</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a1faa_level0_row0" class="row_heading level0 row0" >User ID</th>
#       <td id="T_a1faa_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_a1faa_row0_col1" class="data row0 col1" >0.017647</td>
#       <td id="T_a1faa_row0_col2" class="data row0 col2" >0.006541</td>
#       <td id="T_a1faa_row0_col3" class="data row0 col3" >0.015911</td>
#     </tr>
#     <tr>
#       <th id="T_a1faa_level0_row1" class="row_heading level0 row1" >Age</th>
#       <td id="T_a1faa_row1_col0" class="data row1 col0" >0.017647</td>
#       <td id="T_a1faa_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_a1faa_row1_col2" class="data row1 col2" >0.166042</td>
#       <td id="T_a1faa_row1_col3" class="data row1 col3" >0.616036</td>
#     </tr>
#     <tr>
#       <th id="T_a1faa_level0_row2" class="row_heading level0 row2" >AnnualSalary</th>
#       <td id="T_a1faa_row2_col0" class="data row2 col0" >0.006541</td>
#       <td id="T_a1faa_row2_col1" class="data row2 col1" >0.166042</td>
#       <td id="T_a1faa_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_a1faa_row2_col3" class="data row2 col3" >0.364974</td>
#     </tr>
#     <tr>
#       <th id="T_a1faa_level0_row3" class="row_heading level0 row3" >Purchased</th>
#       <td id="T_a1faa_row3_col0" class="data row3 col0" >0.015911</td>
#       <td id="T_a1faa_row3_col1" class="data row3 col1" >0.616036</td>
#       <td id="T_a1faa_row3_col2" class="data row3 col2" >0.364974</td>
#       <td id="T_a1faa_row3_col3" class="data row3 col3" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
sns.pairplot(df)

# %%
df
# Out:
#      User ID  Gender  Age  AnnualSalary  Purchased
# 0        385    Male   35         20000          0
# 1        681    Male   40         43500          0
# 2        353    Male   49         74000          0
# 3        895    Male   40        107500          1
# 4        661    Male   25         79000          0
# ..       ...     ...  ...           ...        ...
# 995      863    Male   38         59000          0
# 996      800  Female   47         23500          0
# 997      407  Female   28        138500          1
# 998      299  Female   48        134000          1
# 999      687  Female   44         73500          0
#
# [1000 rows x 5 columns]

# %%
def make_one_hot_encoding(df):
    
    encoder = LabelEncoder()
    df["Gender"] = encoder.fit_transform(df["Gender"])
    return df
df1 = make_one_hot_encoding(df)
df1
# Out:
#      User ID  Gender  Age  AnnualSalary  Purchased
# 0        385       1   35         20000          0
# 1        681       1   40         43500          0
# 2        353       1   49         74000          0
# 3        895       1   40        107500          1
# 4        661       1   25         79000          0
# ..       ...     ...  ...           ...        ...
# 995      863       1   38         59000          0
# 996      800       0   47         23500          0
# 997      407       0   28        138500          1
# 998      299       0   48        134000          1
# 999      687       0   44         73500          0
#
# [1000 rows x 5 columns]

# %%
df
# Out:
#      User ID  Gender  Age  AnnualSalary  Purchased
# 0        385       1   35         20000          0
# 1        681       1   40         43500          0
# 2        353       1   49         74000          0
# 3        895       1   40        107500          1
# 4        661       1   25         79000          0
# ..       ...     ...  ...           ...        ...
# 995      863       1   38         59000          0
# 996      800       0   47         23500          0
# 997      407       0   28        138500          1
# 998      299       0   48        134000          1
# 999      687       0   44         73500          0
#
# [1000 rows x 5 columns]
